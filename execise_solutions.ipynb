# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv('data/train.csv')

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
print("Rows:{} Columns:{}".format(df.shape[0], df.shape[1]))
# Out:
# Rows:891 Columns:12

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df=df.set_index("PassengerId")

# %%
s1=df.Age

# %%
np.sum(s1<15)/df.shape[0]
# Out:
# 0.08754208754208755

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
np.sum(s1.isnull())
# Out:
# 177

# %%
sub_df=df[df.Survived==0]
sub_df
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 1                   0       3                   Braund, Mr. Owen Harris
# 5                   0       3                  Allen, Mr. William Henry
# 6                   0       3                          Moran, Mr. James
# 7                   0       1                   McCarthy, Mr. Timothy J
# 8                   0       3            Palsson, Master. Gosta Leonard
# ...               ...     ...                                       ...
# 885                 0       3                    Sutehall, Mr. Henry Jr
# 886                 0       3      Rice, Mrs. William (Margaret Norton)
# 887                 0       2                     Montvila, Rev. Juozas
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
# 891                 0       3                       Dooley, Mr. Patrick
#
#                 Sex   Age  SibSp  Parch           Ticket     Fare Cabin  \
# PassengerId
# ...

# %%
sub_s1=sub_df.Age

# %%
np.sum(sub_s1.isnull())
# Out:
# 125

# %%
nd1=df.Survived

# %%
np.sum(nd1==1)/len(nd1)
# Out:
# 0.3838383838383838

# %%
df1=df.drop(columns="Cabin")
df1
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
np.mean(df1.Age)
# Out:
# 29.69911764705882

# %%
sub_df1=df1[(df1.Age>=10) & (df1.Age<=15)]
sub_df1
# Out:
#              Survived  Pclass                                     Name  \
# PassengerId
# 10                  1       2      Nasser, Mrs. Nicholas (Adele Achem)
# 15                  0       3     Vestrom, Miss. Hulda Amanda Adolfina
# 23                  1       3              McGowan, Miss. Anna "Annie"
# 40                  1       3              Nicola-Yarred, Miss. Jamila
# 60                  0       3       Goodwin, Master. William Frederick
# 112                 0       3                     Zabour, Miss. Hileni
# 126                 1       3             Nicola-Yarred, Master. Elias
# 353                 0       3                       Elias, Mr. Tannous
# 420                 0       3                Van Impe, Miss. Catharina
# 436                 1       1                Carter, Miss. Lucile Polk
# 447                 1       2        Mellinger, Miss. Madeleine Violet
# 543                 0       3        Andersson, Miss. Sigrid Elisabeth
# ...

# %%
np.sum(df1.isnull())
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Embarked      2
# dtype: int64

# %%
df1.Age=df1.Age.fillna(np.mean(df1.Age))

# %%
df1
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# ...                                                        ...     ...
# ...

# %%
df1.Sex=np.where(df1.Sex=="male",1,0)

# %%
X=df1[["Age","SibSp","Parch","Fare","Pclass","Sex"]].values.astype('float')
X
# Out:
# array([[22.        ,  1.        ,  0.        ,  7.25      ,  3.        ,
#          1.        ],
#        [38.        ,  1.        ,  0.        , 71.2833    ,  1.        ,
#          0.        ],
#        [26.        ,  0.        ,  0.        ,  7.925     ,  3.        ,
#          0.        ],
#        ...,
#        [29.69911765,  1.        ,  2.        , 23.45      ,  3.        ,
#          0.        ],
#        [26.        ,  0.        ,  0.        , 30.        ,  1.        ,
#          1.        ],
#        [32.        ,  0.        ,  0.        ,  7.75      ,  3.        ,
#          1.        ]])

# %%
y=df1.Survived.values

# %%
plt.scatter(X,df.Survived)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-94c891bac025> in <module>
# ----> 1 plt.scatter(X,df.Survived)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2872         verts=cbook.deprecation._deprecated_parameter,
#    2873         edgecolors=None, *, plotnonfinite=False, data=None, **kwargs):
# -> 2874     __ret = gca().scatter(
#    2875         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2876         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# ...
